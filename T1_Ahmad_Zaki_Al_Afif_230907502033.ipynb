# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

def scrape_website(url, user_agent='Mozilla/5.0'):
    print(f"Mengakses URL: {url}")

    # Mengirim permintaan HTTP ke URL target
    try:
        headers = {'User-Agent': user_agent}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error saat mengakses URL: {e}")
        return None

    # Parsing HTML dari halaman web menggunakan BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Menyiapkan list untuk menampung semua data
    collected_data = []

    # Menemukan semua artikel. Di berbagai website, artikel sering dibungkus dalam tag <article>, <div>, atau tag lainnya
    articles = soup.find_all('article')  # Bisa diganti dengan tag atau kelas lainnya
    print(f"Menemukan {len(articles)} total artikel.")

    for article in articles:
        # Mencari judul (misalnya dalam <h2> atau tag lainnya)
        title_tag = article.find('h2')  # Anda bisa ganti tag sesuai dengan struktur website
        if not title_tag:
            continue

        title = title_tag.get_text(strip=True)

        # Mencari link dari tag <a> yang membungkus artikel
        link_tag = article.find('a')
        link = link_tag['href'] if link_tag and link_tag.has_attr('href') else 'Tidak ada link'

        # Mengambil URL Gambar Utama (Image URL)
        image_tag = article.find('img')
        image_url = image_tag['src'] if image_tag and image_tag.has_attr('src') else 'Tidak ada gambar'

        # Mencari kategori atau informasi lain jika ada
        category_tag = article.find('span', class_='category')  # Misalnya kategori ada di <span> dengan class 'category'
        category = category_tag.get_text(strip=True) if category_tag else 'Tidak ada kategori'

        # Mengambil waktu, penulis, atau ringkasan jika ada
        publication_time = 'Tidak ada waktu'
        author = 'Tidak diketahui'
        summary = 'Tidak ada ringkasan'

        # Mengumpulkan data jika judul dan link ditemukan
        if title and link != 'Tidak ada link':
            article_data = {
                'title': title,
                'link': link,
                'category': category,
                'publication_time': publication_time,
                'author': author,
                'image_url': image_url,
                'summary': summary
            }
            collected_data.append(article_data)

    # --- Proses Ekspor Hasil ---
    if not collected_data:
        print("Tidak ada data yang berhasil di-scrape. Mungkin struktur website telah berubah.")
    else:
        print(f"Berhasil mengumpulkan {len(collected_data)} artikel yang valid. Mengekspor ke file...")

        # Mengubah nama file output
        file_name_base = 'scraped_data'

        output_json_data = {"list_post": collected_data}
        with open(f'{file_name_base}.json', 'w', encoding='utf-8') as f:
            json.dump(output_json_data, f, ensure_ascii=False, indent=4)
        print(f"Data berhasil diekspor ke {file_name_base}.json")

        df = pd.DataFrame(collected_data)
        df.to_csv(f'{file_name_base}.csv', index=False, encoding='utf-8')
        print(f"Data berhasil diekspor ke {file_name_base}.csv")

        df.to_excel(f'{file_name_base}.xlsx', index=False)
        print(f"Data berhasil diekspor ke {file_name_base}.xlsx")

    return collected_data

# Gunakan fungsi dengan URL yang berbeda untuk scraping
url = 'https://fajar.co.id/'
scrape_website(url)
# Out:
# Mengakses URL: https://fajar.co.id/
# Menemukan 25 total artikel.
# Berhasil mengumpulkan 25 artikel yang valid. Mengekspor ke file...
# Data berhasil diekspor ke scraped_data.json
# Data berhasil diekspor ke scraped_data.csv
# Data berhasil diekspor ke scraped_data.xlsx
# [{'title': 'Integrasi Data dengan Dukcapil Percepat Proses Layanan BRI',
#   'link': 'https://fajar.co.id/2025/09/15/integrasi-data-dengan-dukcapil-percepat-proses-layanan-bri/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/bri-2-3-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'PBNU Terseret Kasus Dugaan Korupsi Kuota Haji 2024, Sekjen Gus Ipul Tegaskan Ini',
#   'link': 'https://fajar.co.id/2025/09/15/pbnu-terseret-kasus-dugaan-korupsi-kuota-haji-2024-sekjen-gus-ipul-tegaskan-ini/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/gus-ipul-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Proses SPMB Minta Ditinjau Ulang, Tamsil Linrung Pertanyakan Indikator Sekolah Unggulan',
#   'link': 'https://fajar.co.id/2025/09/15/proses-spmb-minta-ditinjau-ulang-tamsil-linrung-pertanyakan-indikator-sekolah-unggulan/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/tamsil-linrung-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Bank hanya Sanggup Serap Rp7 Triliun dari Rp200 Triliun Bantuan Likuiditas, Menkeu: Biar Mereka Mikir',
#   'link': 'https://fajar.co.id/2025/09/15/bank-hanya-sanggup-serap-rp7-triliun-dari-rp200-triliun-bantuan-likuiditas-menkeu-biar-mereka-mikir/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/purbaya-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Hadapi Persija Jakarta, Chemistry Lini Tengah PSM Harus Segera Padu',
#   'link': 'https://fajar.co.id/2025/09/15/hadapi-persija-jakarta-chemistry-lini-tengah-psm-harus-segera-padu/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/savio-roberto-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Kecewa Pernyataan Merendahkan PPPK, Nur Baitih Desak Kepala BKN Minta Maaf',
#   'link': 'https://fajar.co.id/2025/09/15/kecewa-pernyataan-merendahkan-pppk-nur-baitih-desak-kepala-bkn-minta-maaf/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/nur-baitih-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Tak Mau Terlena, Marc Marquez Tetap Tenang untuk Kunci Gelar Juara Dunia MotoGP 2025',
#   'link': 'https://fajar.co.id/2025/09/15/tak-mau-terlena-marc-marquez-tetap-tenang-untuk-kunci-gelar-juara-dunia-motogp-2025/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/Marc-Marquez-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Ustaz Khalid Basalamah Kembalikan Uang kepada KPK, Berapa Jumlahnya?',
#   'link': 'https://fajar.co.id/2025/09/15/ustaz-khalid-basalamah-kembalikan-uang-kepada-kpk-berapa-jumlahnya/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/khalid-basalamah-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Tokoh Pemuda Makassar Nilai Andi Seto Asapa Layak Isi Kursi Menpora',
#   'link': 'https://fajar.co.id/2025/09/15/tokoh-pemuda-makassar-nilai-andi-seto-asapa-layak-isi-kursi-menpora/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2024/11/andi-seto-prabowo-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'KPU Tetapkan 16 Dokumen Capres-Cawapres Bukan Informasi Publik, Efek Jokowi?',
#   'link': 'https://fajar.co.id/2025/09/15/kpu-tetapkan-16-dokumen-capres-cawapres-bukan-informasi-publik-efek-jokowi/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/afifuddin-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Lewat Kopdes Merah Putih, Airlangga Hartarto Sebut Serap 1 Juta Lapangan Kerja',
#   'link': 'https://fajar.co.id/2025/09/15/lewat-kopdes-merah-putih-airlangga-hartarto-sebut-serap-1-juta-lapangan-kerja/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/airlangga-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Mahasiswa Tuntut Dicopot, Rektor UNM: Kita Hargai Proses Hukum yang Berjalan',
#   'link': 'https://fajar.co.id/2025/09/15/mahasiswa-tuntut-dicopot-rektor-unm-kita-hargai-proses-hukum-yang-berjalan/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/08/prof-karta-jayadi-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Bukan hanya Siswa, Guru Juga Bakal Jadi Sasaran Program MBG',
#   'link': 'https://fajar.co.id/2025/09/15/bukan-hanya-siswa-guru-juga-bakal-jadi-sasaran-program-mbg/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/menu-mbg-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'DMC Dompet Dhuafa Terus Respons Banjir Bali, Hadirkan Psychological First Aid hingga Distribusi Bantuan bagi Penyintas',
#   'link': 'https://fajar.co.id/2025/09/15/dmc-dompet-dhuafa-terus-respons-banjir-bali-hadirkan-psychological-first-aid-hingga-distribusi-bantuan-bagi-penyintas/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/dompet-duafa-2-250x190.jpeg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Reformasi Kepolisian, PBHI Khawatir Sekadar Jadi Gimmick',
#   'link': 'https://fajar.co.id/2025/09/15/reformasi-kepolisian-pbhi-khawatir-sekadar-jadi-gimmick/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/julius-ibrani-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Lisa Mariana 1.000 Persen Yakin Putrinya Anak Ridwan Kamil, Akankah Polri akan Setujui Tes DNA di Singapura?',
#   'link': 'https://fajar.co.id/2025/09/15/lisa-mariana-1-000-persen-yakin-putrinya-anak-ridwan-kamil-akankah-polri-akan-setujui-tes-dna-di-singapura/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/08/lisa-mariana-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'PSM Makassar Berambisi Raih Kemenangan Perdana, Bisakah Persija Pertahankan Rekor Tak Terkalahkan?',
#   'link': 'https://fajar.co.id/2025/09/15/psm-makassar-berambisi-raih-kemenangan-perdana-bisakah-persija-pertahankan-rekor-tak-terkalahkan/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/persija-jakarta-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Mentan Amran Yakinkan DPD RI, Indonesia Tatap Swasembada Pangan',
#   'link': 'https://fajar.co.id/2025/09/15/mentan-amran-yakinkan-dpd-ri-indonesia-tatap-swasembada-pangan/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/IMG-20250915-WA0330-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Buntut Chat Ayo Goyang Yuk, Mahasiswa UNM Tuntut Rektor Dicopot',
#   'link': 'https://fajar.co.id/2025/09/15/buntut-chat-ayo-goyang-yuk-mahasiswa-unm-tuntut-rektor-dicopot/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/mahasiswa-unm-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Dokter Tifa Ungkit Korban Kanjuruhan hingga KM 50. Singgung Jokowi?',
#   'link': 'https://fajar.co.id/2025/09/15/dokter-tifa-ungkit-korban-kanjuruhan-hingga-km-50-singgung-jokowi/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/05/IMG-20250524-WA0011-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Sidang Gugatan Rp125 Triliun, Gibran Pasang Tameng Tunjuk Tiga Pengacara Top',
#   'link': 'https://fajar.co.id/2025/09/15/sidang-gugatan-rp125-triliun-gibran-pasang-tameng-tunjuk-tiga-pengacara-top/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/07/IMG_0988-250x190.jpeg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Putri Bos Jalan Tol Dipanggil Kejagung, Terkait Kasus Konsesi Cawang-Pluit',
#   'link': 'https://fajar.co.id/2025/09/15/putri-bos-jalan-tol-dipanggil-kejagung-terkait-kasus-konsesi-cawang-pluit/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/037602500_1587018952-hl_37373-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Pilihan Berat untuk Megawati Hangestri, Berlaga di Final Four atau Kembali ke Liga 2 Voli Turki 2025/2026',
#   'link': 'https://fajar.co.id/2025/09/15/pilihan-berat-untuk-megawati-hangestri-berlaga-di-final-four-atau-kembali-ke-liga-2-voli-turki-2025-2026/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/09/download-2025-09-03T090115.209-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Kejar Pengisian DRH PPPK Paruh Waktu, Pemohon SKCK Membludak',
#   'link': 'https://fajar.co.id/2025/09/15/kejar-pengisian-drh-pppk-paruh-waktu-pemohon-skck-membludak/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/07/pppk-250x190.webp',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'P2G Kritik PPPK Paruh Waktu: Kebijakan Absurd, Guru Jadi Terbelah-Belah',
#   'link': 'https://fajar.co.id/2025/09/15/p2g-kritik-pppk-paruh-waktu-kebijakan-absurd-guru-jadi-terbelah-belah/',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://fajar.co.id/wp-content/uploads/2025/07/IMG-20250731-WA0021-250x190.jpg',
#   'summary': 'Tidak ada ringkasan'}]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

def scrape_website(url, user_agent='Mozilla/5.0'):
    print(f"Mengakses URL: {url}")

    # Mengirim permintaan HTTP ke URL target
    try:
        headers = {'User-Agent': user_agent}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error saat mengakses URL: {e}")
        return None

    # Parsing HTML dari halaman web menggunakan BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Menyiapkan list untuk menampung semua data
    collected_data = []

    # Menemukan semua artikel. Di berbagai website, artikel sering dibungkus dalam tag <article>, <div>, atau tag lainnya
    articles = soup.find_all('article')  # Bisa diganti dengan tag atau kelas lainnya
    print(f"Menemukan {len(articles)} total artikel.")

    for article in articles:
        # Mencari judul (misalnya dalam <h2> atau tag lainnya)
        title_tag = article.find('h2')  # Anda bisa ganti tag sesuai dengan struktur website
        if not title_tag:
            continue

        title = title_tag.get_text(strip=True)

        # Mencari link dari tag <a> yang membungkus artikel
        link_tag = article.find('a')
        link = link_tag['href'] if link_tag and link_tag.has_attr('href') else 'Tidak ada link'

        # Mengambil URL Gambar Utama (Image URL)
        image_tag = article.find('img')
        image_url = image_tag['src'] if image_tag and image_tag.has_attr('src') else 'Tidak ada gambar'

        # Mencari kategori atau informasi lain jika ada
        category_tag = article.find('span', class_='category')  # Misalnya kategori ada di <span> dengan class 'category'
        category = category_tag.get_text(strip=True) if category_tag else 'Tidak ada kategori'

        # Mengambil waktu, penulis, atau ringkasan jika ada
        publication_time = 'Tidak ada waktu'
        author = 'Tidak diketahui'
        summary = 'Tidak ada ringkasan'

        # Mengumpulkan data jika judul dan link ditemukan
        if title and link != 'Tidak ada link':
            article_data = {
                'title': title,
                'link': link,
                'category': category,
                'publication_time': publication_time,
                'author': author,
                'image_url': image_url,
                'summary': summary
            }
            collected_data.append(article_data)

    # --- Proses Ekspor Hasil ---
    if not collected_data:
        print("Tidak ada data yang berhasil di-scrape. Mungkin struktur website telah berubah.")
    else:
        print(f"Berhasil mengumpulkan {len(collected_data)} artikel yang valid. Mengekspor ke file...")

        # Mengubah nama file output
        file_name_base = 'scraped_data'

        output_json_data = {"list_post": collected_data}
        with open(f'{file_name_base}.json', 'w', encoding='utf-8') as f:
            json.dump(output_json_data, f, ensure_ascii=False, indent=4)
        print(f"Data berhasil diekspor ke {file_name_base}.json")

        df = pd.DataFrame(collected_data)
        df.to_csv(f'{file_name_base}.csv', index=False, encoding='utf-8')
        print(f"Data berhasil diekspor ke {file_name_base}.csv")

        df.to_excel(f'{file_name_base}.xlsx', index=False)
        print(f"Data berhasil diekspor ke {file_name_base}.xlsx")

    return collected_data

# Gunakan fungsi dengan URL yang berbeda untuk scraping
url = 'https://www.cnnindonesia.com/'
scrape_website(url)
# Out:
# Mengakses URL: https://www.cnnindonesia.com/
# Menemukan 104 total artikel.
# Berhasil mengumpulkan 30 artikel yang valid. Mengekspor ke file...
# Data berhasil diekspor ke scraped_data.json
# Data berhasil diekspor ke scraped_data.csv
# Data berhasil diekspor ke scraped_data.xlsx
# [{'title': 'Pramono Resmikan Gereja di Lubang Buaya Jakarta Timur',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915070133-20-1273673/pramono-resmikan-gereja-di-lubang-buaya-jakarta-timur',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/15/gubernur-dki-pramono-resmikan-gereja-kalvari-1757895330886_11.jpeg?w=100&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Pramono Harap Proyek Bikin Macet di Simatupang Selesai Oktober',
#   'link': 'https://www.cnnindonesia.com/nasional/20250914173208-20-1273600/pramono-harap-proyek-bikin-macet-di-simatupang-selesai-oktober',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/08/21/usai-diguyur-hujan-tb-simatupang-macet-parah-saat-jam-pulang-kerja-1755733364283_11.jpeg?w=100&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'KPK Terima Pengembalian Uang dari Khalid Basalamah Terkait Kuota Haji',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915170658-32-1273956/kpk-terima-pengembalian-uang-dari-khalid-basalamah-terkait-kuota-haji',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'Tidak ada gambar',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Ini Beda Manfaat Jalan Kaki Pagi vs Sore buat Turunkan Berat Badan',
#   'link': 'https://www.cnnindonesia.com/gaya-hidup/20250902114605-255-1269175/ini-beda-manfaat-jalan-kaki-pagi-vs-sore-buat-turunkan-berat-badan',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'Tidak ada gambar',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Timor Leste Ricuh! Mahasiswa Bentrok ke Polisi soal Mobil Baru DPR',
#   'link': 'https://www.cnnindonesia.com/internasional/20250915192419-106-1274005/timor-leste-ricuh-mahasiswa-bentrok-ke-polisi-soal-mobil-baru-dpr',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'Tidak ada gambar',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Komisi II DPR Tegur KPU Rahasiakan Dokumen Syarat Capres-Cawapres',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915185502-32-1274001/komisi-ii-dpr-tegur-kpu-rahasiakan-dokumen-syarat-capres-cawapres',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'Tidak ada gambar',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Jadwal Bioskop Trans TV 15-21 September 2025',
#   'link': 'https://www.cnnindonesia.com/hiburan/20250915143117-220-1273880/jadwal-bioskop-trans-tv-15-21-september-2025',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'Tidak ada gambar',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'KPK Bicara soal Peluang Panggil Ketua Umum PBNU Terkait Kuota Haji',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915193147-12-1274015/kpk-bicara-soal-peluang-panggil-ketua-umum-pbnu-terkait-kuota-haji',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'Tidak ada gambar',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Balas Ejekan, Marquez Selebrasi GOAT Messi di MotoGP San Marino',
#   'link': 'https://www.cnnindonesia.com/olahraga/20250915055028-156-1273652/balas-ejekan-marquez-selebrasi-goat-messi-di-motogp-san-marino',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/15/motogp-1757890775188_169.jpeg?w=170&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Intip Daftar Saham Pendulang Cuan Pekan Ini, Tak Cuma Perbankan',
#   'link': 'https://www.cnnindonesia.com/ekonomi/20250915064723-92-1273670/intip-daftar-saham-pendulang-cuan-pekan-ini-tak-cuma-perbankan',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2018/05/24/8a327b4d-4a05-4a8c-b406-86ed6a91f697_169.jpeg?w=170&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': "Albania Tunjuk AI Jadi 'Menteri' Berantas Korupsi",
#   'link': 'https://www.cnnindonesia.com/internasional/20250915071557-134-1273676/albania-tunjuk-ai-jadi-menteri-berantas-korupsi',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2023/06/07/ilustrasi-artificial-intelligence-ilustrasi-ai-ilustrasi-kecerdasan-buatan-4_169.jpeg?w=170&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'PCO soal Video Prabowo di Layar Bioskop: Pesan Komersial Saja Boleh',
#   'link': 'https://www.cnnindonesia.com/nasional/20250914214816-20-1273631/pco-soal-video-prabowo-di-layar-bioskop-pesan-komersial-saja-boleh',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/08/prabowo-subianto-reshuffle-kabinet-1757322361700_169.png?w=170&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Hasil Liga Inggris: Man City Bantai MU, Haaland Borong 2 Gol',
#   'link': 'https://www.cnnindonesia.com/olahraga/20250914233656-142-1273640/hasil-liga-inggris-man-city-bantai-mu-haaland-borong-2-gol',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/14/soccer-england-mci-mun-1757868550352_169.jpeg?w=170&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Janice Tjen Runner Up Sao Paulo Open 2025',
#   'link': 'https://www.cnnindonesia.com/olahraga/20250915024248-170-1273643/janice-tjen-runner-up-sao-paulo-open-2025',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/08/28/janice-tjen-vs-emma-raducanu-1756315844687_169.jpeg?w=170&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Gibran Kerahkan 3 Pengacara Hadapi Gugatan Rp125 T, Sidang Ditunda',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915113617-12-1273775/gibran-kerahkan-3-pengacara-hadapi-gugatan-rp125-t-sidang-ditunda',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/08/15/wapres-gibran-rakabuming-raka-kiri-mengikuti-sidang-tahunan-mpr-ri-dan-sidang-bersama-dpr-dpd-ri-tahun-2025-1755230620483_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'KPK Terima Pengembalian Uang dari Khalid Basalamah Terkait Kuota Haji',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915170658-32-1273956/kpk-terima-pengembalian-uang-dari-khalid-basalamah-terkait-kuota-haji',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/09/khalid-basalamah-diperiksa-kpk-1757392286347_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Hasil Pemain Abroad Timnas: Idzes Cs Hajar Lazio, Sananta Cetak Gol',
#   'link': 'https://www.cnnindonesia.com/olahraga/20250915051503-142-1273650/hasil-pemain-abroad-timnas-idzes-cs-hajar-lazio-sananta-cetak-gol',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/08/30/cremonese-vs-sassuolo-1756508572711_169.webp?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Tim Ekspedisi TNI AD Temukan 19 Macan Tutul di Karawang',
#   'link': 'https://www.cnnindonesia.com/nasional/20250914212527-20-1273629/tim-ekspedisi-tni-ad-temukan-19-macan-tutul-di-karawang',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/14/macan-tutul-jawa-di-gunung-sanggabuana-1757849802987_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Menhut Buat Tim Percepatan Penetapan Hutan Adat: Ada 1,4 Juta Hektare',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915143041-20-1273890/menhut-buat-tim-percepatan-penetapan-hutan-adat-ada-14-juta-hektare',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2024/10/23/menteri-kehutanan-raja-juli-antoni-3_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'KPU Beber Rahasiakan 16 Dokumen Capres-Cawapres Termasuk Ijazah',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915175511-32-1273966/kpu-beber-rahasiakan-16-dokumen-capres-cawapres-termasuk-ijazah',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2024/07/04/kpu-tunjuk-mochammad-afifuddin-jadi-plt-ketua-kpu-9_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Polda Metro Jaya Buka Posko Pengaduan Orang Hilang di Demo Agustus',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915203840-12-1274027/polda-metro-jaya-buka-posko-pengaduan-orang-hilang-di-demo-agustus',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/15/kapolda-metro-jaya-irjen-asep-edi-suheri-1757943357471_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Serabut Putih pada Lapisan Daging Jeruk, Amankah Dimakan?',
#   'link': 'https://www.cnnindonesia.com/gaya-hidup/20250910135420-262-1272134/serabut-putih-pada-lapisan-daging-jeruk-amankah-dimakan',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2014/12/03/81685e4a-5b7c-4d63-a505-c53151e8f370_169.jpg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': "'Nrimo' Dapat Rp280 M, Erick Thohir Tak Minta Tambahan Anggaran ke DPR",
#   'link': 'https://www.cnnindonesia.com/ekonomi/20250915141415-92-1273860/nrimo-dapat-rp280-m-erick-thohir-tak-minta-tambahan-anggaran-ke-dpr',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/08/18/erick-thohir-1755505248913_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Anak 14 Tahun Ikut Jadi Tersangka Perusakan saat Aksi Demo Jakarta',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915201953-12-1274020/anak-14-tahun-ikut-jadi-tersangka-perusakan-saat-aksi-demo-jakarta',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/15/konpers-pelaku-pengrusakan-demonstrasi-1757941417299_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Bintang Irak: Kami Sudah Tahu Kekuatan Timnas Indonesia',
#   'link': 'https://www.cnnindonesia.com/olahraga/20250915202431-142-1274022/bintang-irak-kami-sudah-tahu-kekuatan-timnas-indonesia',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2024/06/06/timnas-indonesia-vs-irak-di-kualifikasi-piala-dunia-2026-18_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Mendagri Tito Perintahkan Tunjangan Rumah DPRD Segera Dievaluasi',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915163828-32-1273942/mendagri-tito-perintahkan-tunjangan-rumah-dprd-segera-dievaluasi',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2024/08/21/raker-badan-legislasi-dpr-dengan-menkumham-dan-mendagri-terkait-ruu-pilkada-3_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'VIDEO: Uji Coba GT Fatmawati 2 Mulai Senin Sore',
#   'link': 'https://www.cnnindonesia.com/tv/20250915195441-400-1274021/video-uji-coba-gt-fatmawati-2-mulai-senin-sore',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/15/uji-coba-gt-fatmawati-2-mulai-senin-sore-1757942622158_169.png?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Polda Metro Ungkap Bukti Perusakan Fasum: Molotov, Batu hingga Petasan',
#   'link': 'https://www.cnnindonesia.com/nasional/20250915201000-12-1274018/polda-metro-ungkap-bukti-perusakan-fasum-molotov-batu-hingga-petasan',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/15/polisi-tetapkan-16-tersangka-perusakan-saat-aksi-demo-jakarta-1757942559263_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'FOTO: Ramai Simbol Dukungan untuk Palestina di Emmy Awards 2025',
#   'link': 'https://www.cnnindonesia.com/hiburan/20250915133548-236-1273834/foto-ramai-simbol-dukungan-untuk-palestina-di-emmy-awards-2025',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2025/09/15/simbol-dukungan-untuk-gaza-di-karpet-merah-emmy-award-1757918078170_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'},
#  {'title': 'Basuki Usai DPR Tolak Tambah Anggaran IKN Rp14 T: Bisa Mundur Lagi',
#   'link': 'https://www.cnnindonesia.com/ekonomi/20250915193140-92-1274014/basuki-usai-dpr-tolak-tambah-anggaran-ikn-rp14-t-bisa-mundur-lagi',
#   'category': 'Tidak ada kategori',
#   'publication_time': 'Tidak ada waktu',
#   'author': 'Tidak diketahui',
#   'image_url': 'https://akcdn.detik.net.id/visual/2024/12/31/kepala-otorita-basuki-hadimuljono_169.jpeg?w=280&q=90',
#   'summary': 'Tidak ada ringkasan'}]
